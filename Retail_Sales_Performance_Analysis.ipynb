# %% [markdown]
# Topic:-Retail Sales Performance Analysis
#
# Submittted By:- Anshita Maturkar
#
# BT ID:- 240051IT
#
# Department:-Information Technology
#
# College:-JD College of Engineering and Management

# %%
# importing Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# importing Dataset 
df = pd.read_csv("Superstore_Cleaned.csv", encoding='latin1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  08-11-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  12-06-2016  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966  11-10-2015  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %% [markdown]
# Conclusion:
#
# The cleaned Superstore dataset was successfully imported into Jupyter Notebook using Pandas. Displaying the first few records using `df.head()` helped verify that the dataset was loaded correctly and allowed an initial understanding of its structure, columns, and contents before proceeding with further analysis.

# %%
 #shape of dataset
df.shape
# Out:
# (9994, 25)

# %% [markdown]
# Conclusion:
#
# The shape of the dataset was checked to identify the total number of records and features present in the dataset. This provided an overview of the dataset size and ensured that the data was ready for further analysis.

# %%
#columns of dataset
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Profit %',
#        'Discount Band', '0rder  Size', 'Delivery Days'],
#       dtype='object')

# %% [markdown]
# Conclusion:
#
# The `df.columns` function was used to display all the column names present in the dataset. This helped in understanding the available variables and identifying the attributes required for further analysis. Familiarity with the column names ensured accurate data manipulation, visualization, and interpretation throughout the project.

# %%
#information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# Conclusion:
#
# The dataset information was examined to understand the type of data stored in each column and to verify the completeness of the dataset. This step confirmed that the data was properly structured and helped identify any missing values or data type issues that could affect the analysis.

# %%
# total sales
total_sales = df['Sales'].sum()   
# total profit
total_profit = df['Profit'].sum() 

print("Total Sales:", round(total_sales,2))
print("Total Profit:", round(total_profit,2))
# Out:
# Total Sales: 2297200.86
# Total Profit: 286397.02

# %% [markdown]
# Conclusion:
#
# The analysis showed that the Superstore generated strong overall sales while maintaining a positive profit. This indicates that the business was performing well during the analyzed period. Monitoring both sales and profit together helps in understanding whether increased sales are actually contributing to business growth and profitability.

# %%
#Region wise Sales
region_sales = df.groupby('Region')['Sales'].sum()  
print(region_sales)
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
#Region-wise sales Graph
region_sales.plot(kind='bar', figsize=(8,5))

plt.title("Region-wise Sales")
plt.xlabel("Region")
plt.ylabel("Sales")

plt.show()

# %% [markdown]
# Conclusion:
#
# The West Region recorded the highest sales contribution among all regions, whereas the South Region generated the lowest sales. This suggests that the West Region has a stronger market presence, while the South Region may require improved marketing strategies and customer engagement to enhance its performance.

# %%
 #Top 5 Customers
top_customers = (
    df.groupby('Customer Name')['Sales']
    .sum()
    .sort_values(ascending=False)
    .head(5)
)

print(top_customers)
# Out:
# Customer Name
# Sean Miller      25043.050
# Tamara Chand     19052.218
# Raymond Buch     15117.339
# Tom Ashbrook     14595.620
# Adrian Barton    14473.571
# Name: Sales, dtype: float64

# %%
 #Top 5 Customers Graph
top_customers.plot(kind='barh', figsize=(8,5))

plt.title("Top 5 Customers")
plt.xlabel("Sales")

plt.show()

# %% [markdown]
# Conclusion:
#
# The top five customers contributed a significant portion of the total revenue. Maintaining strong relationships with these valuable customers through loyalty programs and personalized services can help increase customer retention and support future business growth.

# %%
 #Botton 5 Products causing loss
bottom_products = (
    df.groupby('Product Name')['Profit']
    .sum()
    .sort_values()
    .head(5)
)

print(bottom_products)
# Out:
# Product Name
# Cubify CubeX 3D Printer Double Head Print                  -8879.9704
# Lexmark MX611dhe Monochrome Laser Printer                  -4589.9730
# Cubify CubeX 3D Printer Triple Head Print                  -3839.9904
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases   -2876.1156
# Bush Advantage Collection Racetrack Conference Table       -1934.3976
# Name: Profit, dtype: float64

# %%
 #Bottom 5 products causing loss (Graph)
bottom_products.plot(kind='barh', figsize=(10,5))

plt.title("Bottom 5 Products (Loss)")
plt.xlabel("Profit")

plt.show()

# %% [markdown]
# Conclusion:
#
# The identified products generated negative profits despite contributing to sales. This indicates the need to review their pricing, discount policies, operational costs, and demand patterns. Addressing these issues can help reduce losses and improve overall profitability.

# %%
#Proper Order Date 
df['Order Date'] = pd.to_datetime(
    df['Order Date'],
    format='%d-%m-%Y'
)

df.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12  16-06-2016    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11  18-10-2015  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11  18-10-2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %% [markdown]
# Conclusion:
#
# The Order Date column was converted into the appropriate datetime format to ensure accurate date-based analysis. This transformation enabled the extraction of time-related insights such as monthly trends and year-wise sales growth. Proper date formatting is essential for performing reliable time series analysis and generating meaningful business insights.

# %%
 # Monthly Sales 
monthly_sales = df.groupby(
    df['Order Date'].dt.to_period('M')
)['Sales'].sum()

print(monthly_sales)
# Out:
# Order Date
# 2014-01     14236.8950
# 2014-02      4519.8920
# 2014-03     55691.0090
# 2014-04     28295.3450
# 2014-05     23648.2870
# 2014-06     34595.1276
# 2014-07     33946.3930
# 2014-08     27909.4685
# 2014-09     81777.3508
# 2014-10     31453.3930
# 2014-11     78628.7167
# 2014-12     69545.6205
# 2015-01     18174.0756
# 2015-02     11951.4110
# 2015-03     38726.2520
# 2015-04     34195.2085
# 2015-05     30131.6865
# 2015-06     24797.2920
# 2015-07     28765.3250
# 2015-08     36898.3322
# 2015-09     64595.9180
# 2015-10     31404.9235
# 2015-11     75972.5635
# 2015-12     74919.5212
# 2016-01     18542.4910
# 2016-02     22978.8150
# 2016-03     51715.8750
# 2016-04     38750.0390
# 2016-05     56987.7280
# 2016-06     40344.5340
# 2016-07     39261.9630
# 2016-08     31115.3743
# 2016-09     73410.0249
# 2016-10     59687.7450
# 2016-11     79411.9658
# 2016-12     96999.0430
# 2017-01     43971.3740
# 2017-02     20301.1334
# 2017-03     58872.3528
# ...

# %%
 #Monthly Sales Trend Graph
monthly_sales.plot(figsize=(12,5))

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %% [markdown]
# Conclusion:
#
# The monthly sales trend showed fluctuations throughout the year, with higher sales observed during certain months. This indicates seasonal demand patterns. Understanding these trends can help businesses plan inventory, promotions, and resource allocation more effectively.

# %%
 # Category-wise Sales
category = df.groupby('Category')[['Sales','Profit']].sum()

print(category)
# Out:
#                        Sales       Profit
# Category
# Furniture        741999.7953   18451.2728
# Office Supplies  719047.0320  122490.8008
# Technology       836154.0330  145454.9481

# %%
#Category-wise Sales Graph
category['Sales'].plot(kind='bar', figsize=(8,5))

plt.title("Category-wise Sales")
plt.ylabel("Sales")

plt.show()

# %% [markdown]
# Conclusion:
#
# Among all product categories, Technology performed the best in terms of sales, while the other categories showed comparatively lower contributions. This suggests that investing more in high-performing categories while improving weaker ones can enhance overall business performance.

# %%
 #Segment wise Profit
segment = df.groupby('Segment')[['Sales','Profit']].sum()

segment['Profit Ratio'] = (
    segment['Profit'] /
    segment['Sales']
) * 100

print(segment)
# Out:
#                     Sales       Profit  Profit Ratio
# Segment
# Consumer     1.161401e+06  134119.2092     11.548050
# Corporate    7.061464e+05   91979.1340     13.025506
# Home Office  4.296531e+05   60298.6785     14.034269

# %%
#Segment wise Profit Ratio graph
segment['Profit Ratio'].plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7,7)
)

plt.title("Profit Ratio by Segment")
plt.ylabel("")

plt.show()

# %% [markdown]
# Conclusion:
#
# The profitability of customer segments varied significantly. Some segments contributed more effectively to profit generation than others. Identifying highly profitable customer segments enables businesses to focus their efforts on customers who create greater value.Here Home Office Category generates the highest Profit Ratio.

# %%
 #Average Order Value 
average_order_value = (
    df['Sales'].sum() /
    df['Order ID'].nunique()
)

print(
    "Average Order Value:",
    round(average_order_value,2)
)
# Out:
# Average Order Value: 458.61

# %% [markdown]
# Conclusion:
#
# The average order value provided insights into customer purchasing behavior and spending capacity. Monitoring this metric helps businesses evaluate customer buying patterns and develop strategies to encourage higher-value purchases.

# %%
#Discount vs Profit Impact
high_discount = df[df['Discount'] > 0.30]

impact = high_discount.groupby(
    'Discount'
)['Profit'].mean()

print(impact)
# Out:
# Discount
# 0.32    -88.560656
# 0.40   -111.927429
# 0.45   -226.646464
# 0.50   -310.703456
# 0.60    -43.077212
# 0.70    -95.874060
# 0.80   -101.796797
# Name: Profit, dtype: float64

# %%
 #correlation of Discount between Profit
plt.show    
impact.plot(kind='bar', figsize=(8,5))

plt.title("High Discount Impact")
plt.xlabel("Discount")
plt.ylabel("Average Profit")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Conclusion:
#
# The analysis revealed that orders with higher discounts often resulted in lower profits. While discounts can increase sales volume, excessive discounting can negatively affect earnings. Therefore, businesses should implement discount strategies carefully to maintain profitability.

# %%
#correlation of Discount between Profit
correlation = df[
    ['Discount','Profit']
].corr()

print(correlation)
# Out:
#           Discount    Profit
# Discount  1.000000 -0.219487
# Profit   -0.219487  1.000000

# %%
#correlation of Discount between Profit Graph
plt.figure(figsize=(8,5))

plt.scatter(
    df['Discount'],
    df['Profit']
)

plt.title(
    "Correlation Between Discount and Profit"
)

plt.xlabel("Discount")
plt.ylabel("Profit")

plt.show()

# %% [markdown]
# Conclusion:
#
# The correlation analysis indicated a negative relationship between discounts and profit. As discount levels increased, profitability tended to decrease. This finding highlights the importance of balancing promotional activities with profit objectives to achieve sustainable business g

# %%
#Sales by Ship Mode Graph
ship_mode = df.groupby('Ship Mode')['Sales'].sum()

print(ship_mode)

ship_mode.plot(kind='bar')

plt.title("Sales by Ship Mode")
plt.ylabel("Sales")

plt.show()
# Out:
# Ship Mode
# First Class       3.514284e+05
# Same Day          1.283631e+05
# Second Class      4.591936e+05
# Standard Class    1.358216e+06
# Name: Sales, dtype: float64

# %% [markdown]
# Conclusion:
#
# Standard Class recorded the highest sales, making it the most preferred shipping mode among customers. Same Day shipping generated the lowest sales, indicating lower customer demand for faster delivery options. The company should continue focusing on improving its standard shipping services to maintain customer satisfaction and sales growth.

# %%
#Profit by Sub-Category graph
subcategory = (
    df.groupby('Sub-Category')['Profit']
    .sum()
    .sort_values()
)

subcategory.plot(kind='barh', figsize=(10,7))

plt.title("Profit by Sub-Category")
plt.xlabel("Profit")

plt.show()

# %% [markdown]
# Conclusion:
#
# The analysis reveals that Tables and Machines are the biggest loss-making sub-categories, followed by Phones, Storage, and Supplies. These products require immediate attention to identify the reasons behind poor profitability. Revising pricing strategies, controlling costs, and optimizing discounts can help reduce losses and improve overall business performance.

# %%
# Year wise Sales Growth Graph
yearly_sales = df.groupby(
    df['Order Date'].dt.year
)['Sales'].sum()

print(yearly_sales)

yearly_sales.plot(marker='o')

plt.title("Year-wise Sales Growth")
plt.xlabel("Year")
plt.ylabel("Sales")

plt.show()
# Out:
# Order Date
# 2014    484247.4981
# 2015    470532.5090
# 2016    609205.5980
# 2017    733215.2552
# Name: Sales, dtype: float64

# %% [markdown]
# Conclusion:
# Sales grew significantly from 2014 to 2017, with 2017 recording the highest sales among all years. This upward trend reflects strong business growth and increasing customer engagement. The company should continue the strategies that contributed to this success while identifying opportunities for further expansion.

# %% [markdown]
# Overall Conclusion:-
#
# This analysis successfully explored Superstore sales data using Python to identify important business trends and performance indicators. The study evaluated key aspects such as total sales and profit, regional performance, category-wise contribution, customer behavior, product profitability, discount impact, and sales trends over time.
#
# The findings indicate that the West Region is the strongest contributor to both sales and profit, whereas the South Region shows comparatively lower performance and requires greater business attention. Technology emerged as the highest-performing category, highlighting its significant contribution to revenue generation. The analysis also revealed that a small group of customers accounts for a substantial portion of total sales, emphasizing the importance of customer retention strategies.
#
# Furthermore, Tables and Machines were identified as major loss-making products, suggesting the need to review pricing, discounting practices, and cost structures associated with these items. The monthly sales trend demonstrated seasonal variations, with stronger sales observed during the later months of the year.
#
# Overall, this Python-based analysis transformed raw data into meaningful insights and demonstrated how data analytics can support informed decision-making. The results can help businesses identify opportunities for growth, improve profitability, and develop effective strategies based on data-driven evidence.
